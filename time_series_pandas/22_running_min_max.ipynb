# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/stock_data/sp500.csv', parse_dates=['date'], index_col='date')
data.head()
# Out:
#               SP500
# date
# 2007-06-29  1503.35
# 2007-07-02  1519.43
# 2007-07-03  1524.87
# 2007-07-05  1525.40
# 2007-07-06  1530.44

# %%
# Compute running min and max
data['running_min'] = data['SP500'].expanding().min()
data['running_max'] = data['SP500'].expanding().max()
data.head()
# Out:
#               SP500  running_min  running_max
# date
# 2007-06-29  1503.35      1503.35      1503.35
# 2007-07-02  1519.43      1503.35      1519.43
# 2007-07-03  1524.87      1503.35      1524.87
# 2007-07-05  1525.40      1503.35      1525.40
# 2007-07-06  1530.44      1503.35      1530.44

# %%
# Plot running stats with time series
data.plot()
plt.show()
