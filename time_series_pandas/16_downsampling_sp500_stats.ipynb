# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sp500 = pd.read_csv('data/stock_data/sp500.csv', parse_dates=['date'], index_col='date')
sp500.head()
# Out:
#               SP500
# date
# 2007-06-29  1503.35
# 2007-07-02  1519.43
# 2007-07-03  1524.87
# 2007-07-05  1525.40
# 2007-07-06  1530.44

# %%
# Calculate daily returns and convert to pd.Series() using squeeze()
daily_returns = sp500.squeeze().pct_change()

# %%
# Resample and calculate monthly statistics
stats = daily_returns.resample('M').agg(['mean', 'median', 'std'])

# %%
# Plot stats
stats.plot()
plt.show()
